# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# Colunas tratadas:
#
# - **Variáveis Booleanas/Binárias**:
#     - obito, luz_eletrica, em_situacao_de_rua, possui_plano_saude, vulnerabilidade_social, familia_beneficiaria_auxilio_brasil, crianca_matriculada_creche_pre_escola
#
# - **Variáveis Qualitativas**:
#     - sexo, religiao, renda_familiar, identidade_genero, situacao_profissional, meios_transporte, doencas_condicoes, meios_comunicacao, em_caso_doenca_procura

# %%
df = pd.read_csv('dados_ficha_tratados.csv')
df
# Out:
#                                 id_paciente       sexo  obito  \
# 0      cd6daa6e-038d-4952-af29-579e62e07f97  Masculino      0
# 1      ad6cecb2-3a44-49ab-b2f3-6f9ffc2e2ec7  Masculino      0
# 2      54e834e7-e722-4daa-8909-cf917a1247e6  Masculino      0
# 3      c6a71e5e-0933-48d1-9d5a-8f448dc37f71   Feminino      0
# 4      d5262a3c-e5d3-4195-a46b-0acd2533e1d6  Masculino      0
# ...                                     ...        ...    ...
# 99995  9aa08b9f-44f3-417d-bd1d-66288d7beaae   Feminino      0
# 99996  1b1f7444-8959-4210-b5de-cdfb9b62eab8   Feminino      0
# 99997  2c1d1127-0575-4df1-a879-12734f7cbf39   Feminino      0
# 99998  6a28a1d0-9d1f-4d66-8f28-759083b91f59   Feminino      0
# 99999  d582b5c6-06c6-4741-9fcc-ccbc22d43413   Feminino      0
#
#                 bairro raca_cor                          ocupacao  \
# 0      Parada de Lucas   Branca                     Não se aplica
# 1          Cidade Nova    Parda         Assistente Administrativo
# ...

# %% [markdown]
# **Variáveis binárias**

# %%
columns = ['obito', 'luz_eletrica', 'em_situacao_de_rua', 'possui_plano_saude', 
           'vulnerabilidade_social', 'familia_beneficiaria_auxilio_brasil', 'crianca_matriculada_creche_pre_escola']

for column in columns:
    print(f'Valores únicos da coluna {column}: {df[column].unique()}')
# Out:
# Valores únicos da coluna obito: [0 1]
# Valores únicos da coluna luz_eletrica: [1 0]
# Valores únicos da coluna em_situacao_de_rua: [0 1]
# Valores únicos da coluna possui_plano_saude: [0 1]
# Valores únicos da coluna vulnerabilidade_social: [0 1]
# Valores únicos da coluna familia_beneficiaria_auxilio_brasil: [0 1]
# Valores únicos da coluna crianca_matriculada_creche_pre_escola: [0 1]

# %% [markdown]
# **Variáveis qualitativas**

# %%
columns = ['sexo', 'religiao', 'renda_familiar', 'identidade_genero', 'situacao_profissional', 
           'meios_transporte', 'doencas_condicoes', 'meios_comunicacao', 'em_caso_doenca_procura']

for column in columns:
    print(f'Valores únicos da coluna {column}: {df[column].unique()}\n')
# Out:
# Valores únicos da coluna sexo: ['Masculino' 'Feminino']
#
# Valores únicos da coluna religiao: ['Sem religião' 'Evangélica' 'Católica' 'Outra' 'Espírita'
#  'Religião de matriz africana' 'Não' nan 'Budismo' 'Judaísmo' 'Candomblé'
#  'Islamismo' 'Sim']
#
# Valores únicos da coluna renda_familiar: ['2 Salários Mínimos' '1 Salário Mínimo' '1/2 Salário Mínimo'
#  '4 Salários Mínimos' '3 Salários Mínimos' '1/4 Salário Mínimo'
#  'Mais de 4 Salários Mínimos' nan]
#
# Valores únicos da coluna identidade_genero: ['Cis' 'Não' 'Outro' 'Trans' nan 'Sim' 'Travesti']
#
# Valores únicos da coluna situacao_profissional: ['Emprego Formal' 'Autônomo com previdência social' 'Não se aplica'
#  'Não trabalha' 'Desempregado' 'Outro' 'Autônomo' 'Emprego Informal'
#  'Autônomo sem previdência social' 'Pensionista / Aposentado' 'Empregador'
#  nan]
#
# Valores únicos da coluna meios_transporte: ['Ônibus' 'Carro, Metrô, Ônibus, Trem' 'Carro, Ônibus' 'Metrô, Ônibus'
# ...
